# %%
# VOTRE PREMIER LABO
### Veuillez lire cette section. C'est précieux pour vous préparer, même si c'est long à lire -- c'est important.

## Votre premier projet LLM Frontier

Construisons une solution LLM utile - en quelques minutes.

À la fin de ce cours, vous aurez construit une solution d'IA autonome avec 7 agents qui collaborent pour résoudre un problème commercial. Tout en temps voulu ! Nous commencerons par quelque chose de plus petit...

Notre objectif est de coder un nouveau type de navigateur Web. Donnez-lui une URL, et il répondra avec un résumé. Le Reader's Digest de l'internet !!

Avant de commencer, vous devriez avoir complété la configuration pour [PC](../SETUP-PC.md) ou [Mac](../SETUP-mac.md) et vous avez probablement lancé ce jupyter lab depuis le répertoire racine du projet, avec votre environnement activé.

## Si vous êtes nouveau dans Jupyter Lab

Bienvenue dans le merveilleux monde de l'expérimentation en science des données ! Une fois que vous avez utilisé Jupyter Lab, vous vous demanderez comment vous avez pu vivre sans. Il vous suffit de cliquer dans chaque "cellule" avec du code, comme la cellule immédiatement en dessous de ce texte, et d'appuyer sur Shift+Return pour exécuter cette cellule. Comme vous le souhaitez, vous pouvez ajouter une cellule avec le bouton + dans la barre d'outils, et imprimer les valeurs des variables, ou essayer des variations.

J'ai écrit un carnet appelé [Guide de Jupyter](Guide%20to%20Jupyter.ipynb) pour vous aider à vous familiariser avec Jupyter Labs, y compris l'ajout de commentaires Markdown, l'utilisation de `!` pour exécuter des commandes shell, et `tqdm` pour montrer les progrès.

## Si vous êtes nouveau dans la ligne de commande

Veuillez consulter ces excellents guides : [Ligne de commande sur PC](https://chatgpt.com/share/67b0acea-ba38-8012-9c34-7a2541052665) et [Ligne de commande sur Mac](https://chatgpt.com/canvas/shared/67b0b10c93a081918210723867525d2b).

## Si vous préférez travailler dans des IDE

Si vous êtes plus à l'aise dans des IDE comme VSCode ou Pycharm, ils fonctionnent tous les deux très bien avec ces carnets de laboratoire aussi.
Si vous préférez travailler dans VSCode, [ici](https://chatgpt.com/share/676f2e19-c228-8012-9911-6ca42f8ed766) se trouvent des instructions d'un ami IA sur la façon de le configurer pour le cours.

## Si vous souhaitez réviser votre Python

J'ai ajouté un carnet appelé [Python Intermédiaire](Intermediate%20Python.ipynb) pour vous mettre à jour. Mais vous devriez l'ignorer si vous avez déjà une bonne idée de ce que fait ce code :
`yield from {book.get("author") for book in books if book.get("author")}`

## Je suis là pour aider

Si vous avez des problèmes, n'hésitez pas à me contacter.
Je suis disponible via la plateforme, ou à ed@edwarddonner.com, ou sur https://www.linkedin.com/in/eddonner/ si vous souhaitez vous connecter (et j'adore me connecter !) Et c'est nouveau pour moi, mais j'essaie aussi X/Twitter à [@edwarddonner](https://x.com/edwarddonner) - si vous êtes sur X, montrez-moi comment ça se fait 😄

## Plus de dépannage
