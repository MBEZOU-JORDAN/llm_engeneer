# %%
# Bienvenue à votre premier devoir !

Les instructions sont ci-dessous. Veuillez essayer cela, et regardez dans le dossier des solutions si vous êtes bloqué (ou n'hésitez pas à me demander !)

<table style="margin: 0; text-align: left;">
    <tr>
        <td style="width: 150px; height: 150px; vertical-align: middle;">
            <img src="../resources.jpg" width="150" height="150" style="display: block;" />
        </td>
        <td>
            <h2 style="color:#f71;">Juste avant d'arriver à l'exercice --</h2>
            <span style="color:#f71;">Je pensais que je prendrais une seconde pour vous pointer vers cette page de ressources utiles pour le cours. Cela inclut des liens vers toutes les diapositives.<br/>
            <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
            Veuillez garder cela en favori, et je continuerai à ajouter plus de liens utiles au fil du temps.
            </span>
        </td>
    </tr>
</table>

# DEVOIR D'EXERCICE

Améliorez le projet du jour 1 pour résumer une page Web afin d'utiliser un modèle open source fonctionnant localement via Ollama plutôt qu'OpenAI.

Vous pourrez utiliser cette technique pour tous les projets suivants si vous préférez ne pas utiliser d'API payantes.
# Out:
#   Cell In[1], line 3
#     Les instructions sont ci-dessous. Veuillez essayer cela, et regardez dans le dossier des solutions si vous êtes bloqué (ou n'hésitez pas à me demander !)
#                                                                                                                                 ^
# SyntaxError: unterminated string literal (detected at line 3)
