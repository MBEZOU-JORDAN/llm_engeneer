# %%
# Fin de l'exercice de la semaine 1

Pour démontrer votre familiarité avec l'API OpenAI, et aussi Ollama, construisez un outil qui prend une question technique,  
et répond avec une explication. C'est un outil que vous pourrez utiliser vous-même pendant le cours !
