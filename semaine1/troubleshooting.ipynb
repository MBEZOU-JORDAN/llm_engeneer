# %%
# Oh là là !

Si vous êtes arrivé ici, c'est que vous avez encore des problèmes pour configurer votre environnement. Je suis vraiment désolé ! Accrochez-vous et nous devrions vous faire fonctionner en un rien de temps.

Configurer un environnement de science des données peut être difficile car il y a beaucoup de choses qui se passent en coulisses. Mais nous y arriverons.

Et n'oubliez pas - je suis là pour vous aider. Envoyez-moi un message ou un e-mail à ed@edwarddonner.com et je m'en occuperai. La toute dernière cellule de ce carnet contient des diagnostics qui m'aideront à comprendre ce qui se passe.

## Avant de commencer

### Vérification de votre connexion Internet

Tout d'abord, vérifions qu'il n'y a pas de problème de VPN, de pare-feu ou de certificats.

Cliquez dans la cellule ci-dessous et appuyez sur Shift+Return pour l'exécuter.  
Si cela vous pose des problèmes, essayez de suivre ces instructions pour résoudre :  
https://chatgpt.com/share/676e6e3b-db44-8012-abaa-b3cf62c83eb3

J'ai également entendu dire que vous pourriez avoir des problèmes si vous utilisez un ordinateur de travail qui exécute un logiciel de sécurité zscaler.

Quelques conseils d'étudiants dans cette situation avec zscaler :

> Dans l'invite anaconda, cela a parfois aidé, bien que j'aie encore eu des échecs occasionnels lors de l'exécution de code dans Jupyter :
`conda config --set ssl_verify false`  
Une autre chose qui a aidé était d'ajouter `verify=False` chaque fois qu'il y a `request.get(..)`, donc `request.get(url, headers=headers)` devient `request.get(url, headers=headers, verify=False)`.
