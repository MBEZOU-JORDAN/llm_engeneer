# %%
# Python de niveau intermédiaire

## Vous mettre à jour

Ce cours suppose que vous êtes à un niveau intermédiaire de python. Par exemple, vous devriez avoir une idée décente de ce que quelque chose comme ceci pourrait faire :
`yield from {book.get("author") for book in books if book.get("author")}`

Si ce n'est pas le cas - alors vous êtes au bon endroit ! Bienvenue dans le cours intensif sur le python de niveau intermédiaire. La meilleure façon d'apprendre est de faire !

## D'abord : si vous avez besoin d'un rappel sur les bases

Je vais laisser un ami IA s'en occuper, car ces explications sont si bien écrites avec de bons exemples. Copiez et collez les exemples de code dans une nouvelle cellule pour les essayer. Choisissez la ou les sections que vous souhaitez réviser.

**Imports Python :**  
https://chatgpt.com/share/672f9f31-8114-8012-be09-29ef0d0140fb

**Fonctions Python** y compris les arguments par défaut :  
https://chatgpt.com/share/672f9f99-7060-8012-bfec-46d4cf77d672

**Chaînes Python**, y compris le découpage, le split/join, le remplacement et les littéraux :  
https://chatgpt.com/share/672fb526-0aa0-8012-9e00-ad1687c04518

**f-strings Python** y compris le formatage des nombres et des dates :  
https://chatgpt.com/share/672fa125-0de0-8012-8e35-27918cbb481c

**Listes, dicts et sets Python**, y compris la méthode `get()` :  
https://chatgpt.com/share/672fa225-3f04-8012-91af-f9c95287da8d

**Fichiers Python** y compris les modes, l'encodage, les gestionnaires de contexte, Path, glob.glob :  
https://chatgpt.com/share/673b53b2-6d5c-8012-a344-221056c2f960
