# %%
# Jupyter Lab

## Un guide de démarrage rapide

Bienvenue dans le merveilleux monde de Jupyter lab !  
C'est un terrain de jeu pour la science des données où vous pouvez facilement écrire du code et enquêter sur les résultats. C'est un environnement idéal pour :  
- Recherche & Développement
- Prototypage
- Apprentissage (c'est nous !)

Ce n'est pas typiquement utilisé pour expédier du code de production, et dans la Semaine 8, nous explorerons le pont entre Jupyter et le code python.

Un fichier dans Jupyter Lab, comme celui-ci, s'appelle un **Carnet**.

Il y a longtemps, Jupyter s'appelait "IPython", et donc les extensions des carnets sont ".ipynb" qui signifie "Carnet IPython".

À gauche se trouve un navigateur de fichiers qui vous permet de naviguer dans les répertoires et de choisir différents carnets. Mais vous le savez probablement déjà, sinon vous ne seriez pas arrivé ici !

Le carnet se compose d'une série de cases carrées appelées "cellules". Certaines d'entre elles contiennent du texte, comme cette cellule, et certaines d'entre elles contiennent du code, comme la cellule ci-dessous.

Cliquez dans une cellule avec du code et appuyez sur `Shift + Return` (ou `Shift + Enter`) pour exécuter le code et imprimer la sortie.

Faites cela maintenant pour la cellule ci-dessous :
